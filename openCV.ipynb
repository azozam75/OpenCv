# %% [markdown]
# # Object detection by OpenCV library
#
# ## Install OpenCV library

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\azoz\anaconda3\envs\myenv\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\azoz\anaconda3\envs\myenv\lib\site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Disblay image

# %%
import cv2

img = cv2.imread("Cat.jpg")
cv2.imshow("Cat", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# To convert BGR to RGB, we us a function:

# %%
import cv2

img = cv2.imread("Cat.jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow("image", RGB_img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load classifiers
cat_face = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalcatface.xml"
)

eye_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_eye.xml"
)

# Read image
img = cv2.imread("Cat.jpg")

if img is None:
    print("Image not found!")
    exit()

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect cat face
faces = cat_face.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=3,
    minSize=(60, 60)
)

print("Faces:", len(faces))

for (x, y, w, h) in faces:

    # Draw face
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

    # Detect eyes
    eyes = eye_cascade.detectMultiScale(
        roi_gray,
        scaleFactor=1.05,
        minNeighbors=3,
        minSize=(15, 15)
    )

    print("Eyes:", len(eyes))

    # Draw eyes
    for (ex, ey, ew, eh) in eyes:

        # Ignore detections in lower face
        if ey > h * 0.6:
            continue

        cv2.rectangle(
            roi_color,
            (ex, ey),
            (ex+ew, ey+eh),
            (0,255,0),
            2
        )

cv2.imshow("Cat Eye Detection", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Faces: 1
# Eyes: 2

# %% [markdown]
# # Object Recognition: Russian Plate

# %% [markdown]
# ## 1. Loading the Image

# %%
import cv2
import matplotlib.pyplot as plt   

img = cv2.imread("Russian plate.jpg")

# %% [markdown]
# ## 2. Converting Image Color Formats

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# ## 3. Loading Haar Cascade Classifier

# %%
plate_cascade = cv2.CascadeClassifier('haarcascade_russian_plate_number.xml')

# %% [markdown]
# ## 4. Detecting Objects in the Image

# %%
found = plate_cascade.detectMultiScale(img_gray, minSize=(20, 20))

# %% [markdown]
# ## 5. Drawing Rectangles Around Detected Objects

# %%
for (x, y, w, h) in found:
    cv2.rectangle(img_rgb, (x, y), (x + w, y + h), (0, 255, 0), 5)

plt.imshow(img_rgb)
plt.show()
